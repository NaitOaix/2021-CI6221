# %%
from matplotlib import pyplot as plt
import pandas as pd

TuitionFees = {'Name':['NTU-ComputerScience', 'SMU-BusinessManagement'],'Tutiton Fees':[9400, 11450]}

df = pd.DataFrame(TuitionFees).plot.bar(x='Name', y='Tutiton Fees', rot=0)
plt.xlabel("University")
plt.title("Annual Tuition Fees").set_color('blue')

# %%
plt.savefig("output.jpg", dpi=3000)
